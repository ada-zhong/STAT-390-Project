# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("train.csv", index_col = "id")

# %%
data["y"].describe()
# Out:
# count    5380.000000
# mean        8.630297
# std        12.016238
# min         1.000000
# 25%         2.000000
# 50%         5.000000
# 75%        10.000000
# max       100.000000
# Name: y, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5380 entries, 0 to 5379
# Columns: 766 entries, x001 to y
# dtypes: float64(657), int64(98), object(11)
# memory usage: 31.5+ MB

# %%
data2 = data.select_dtypes(include=[np.object])
# Out:
# <ipython-input-5-13d54095a6f8>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data2 = data.select_dtypes(include=[np.object])

# %%
data2
# Out:
#                                   x039                             x117  \
# id
# 0            1276315487270499940040704  3867048740925900161725707059200
# 1     14307512619168000076472454742016     9465643212201800471249158144
# 2           47525543472235003561115648   270997374075120014554669514752
# 3       924173667994069945955479715840    66286071954144998593205895168
# 4             118694919641369992495104    67561575735033000831477612544
# ...                                ...                              ...
# 5375     72453943382712996379737718784     4047227532757399819819941888
# 5376     29625796361619999610512605184  1028761497912200023014633373696
# 5377      7372025845049799859935117312   502306013176660030195421413376
# 5378           52911462458709996732416    84089205460428997700993679360
# 5379         6374241521617100081201152     7313668279190599994787758080
#
#                                   x154                       x189  \
# id
# ...

# %%
data['x039'] = data['x039'].astype(float)
data['x117'] = data['x117'].astype(float)
data['x154'] = data['x154'].astype(float)
data['x189'] = data['x266'].astype(float)
data['x266'] = data['x266'].astype(float)
data['x320'] = data['x320'].astype(float)
data['x379'] = data['x379'].astype(float)
data['x435'] = data['x435'].astype(float)
data['x689'] = data['x689'].astype(float)
data['x700'] = data['x700'].astype(float)
data['x707'] = data['x707'].astype(float)

# changing all columns with default type as object into float
# seems that all of these columns just include numbers so they shouldn't be an object class

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5380 entries, 0 to 5379
# Columns: 766 entries, x001 to y
# dtypes: float64(668), int64(98)
# memory usage: 31.5 MB

# %%
data["y"].value_counts()
# Out:
# 2     720
# 1     640
# 3     604
# 4     570
# 5     390
#      ...
# 65      1
# 57      1
# 53      1
# 72      1
# 99      1
# Name: y, Length: 81, dtype: int64

# %%
data['y'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
data.y.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
data.corr()
# Out:
#           x001      x002      x003      x004      x005      x006      x007  \
# x001  1.000000 -0.102542  0.153749  0.379679  0.493197  0.247154 -0.165646
# x002 -0.102542  1.000000 -0.177286  0.035330 -0.180123  0.071401  0.463602
# x003  0.153749 -0.177286  1.000000 -0.066532 -0.052850 -0.113437 -0.500092
# x004  0.379679  0.035330 -0.066532  1.000000  0.231413  0.222151  0.126973
# x005  0.493197 -0.180123 -0.052850  0.231413  1.000000  0.166817 -0.061912
# ...        ...       ...       ...       ...       ...       ...       ...
# x762 -0.058439  0.101158 -0.236631  0.046296  0.042812  0.098511  0.366232
# x763  0.629004  0.017972  0.204255  0.225874 -0.128443  0.226026 -0.154933
# x764 -0.149572  0.819495 -0.500867  0.086455 -0.025749  0.116250  0.741603
# x765 -0.005274 -0.022161 -0.005638  0.005585  0.060317 -0.014770 -0.011229
# y     0.002661 -0.065831  0.201294 -0.021558 -0.060656 -0.122274 -0.109782
#
# ...

# %%
correlation = data.corrwith(data['y'])

# inc
