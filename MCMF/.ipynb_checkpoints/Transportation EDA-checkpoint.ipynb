# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mcmf = pd.read_csv('mcmf.csv')
# Out:
# /var/folders/tx/ccgvwwd562sfhw5ybj094vxc0000gn/T/ipykernel_17191/2783852984.py:1: DtypeWarning: Columns (14,28,37,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   mcmf = pd.read_csv('mcmf.csv')

# %%
mcmf = mcmf.drop('Unnamed: 0', axis=1)

# %%
mcmf.head()
# Out:
#   index_row     id                                 program_name  \
# 0     4,568  78752  BBBS Community Based Mentoring (Year Round)
# 1     4,569  78752  BBBS Community Based Mentoring (Year Round)
# 2     4,562  78749        Youth Mentoring and Academic Supports
# 3     4,563  78749        Youth Mentoring and Academic Supports
# 4     4,557  78746                Refugee Youth Career Pathways
#
#                                          description  \
# 0  Community Based Mentoring is the traditional B...
# 1  Community Based Mentoring is the traditional B...
# 2  Young Men's Educational Network provides mento...
# 3  Young Men's Educational Network provides mento...
# 4  Refugee Youth Career Pathways (RYCP) provides ...
#
#                                 org_name     category_name  capacity  min_age  \
# 0               Big Brothers Big Sisters  academic_support    2000.0        7
# 1               Big Brothers Big Sisters       work_career    2000.0        7
# ...

# %%
grouped = mcmf.groupby('geographic_cluster_name').agg({
    'km_to_bus_stop': 'mean',
    'km_to_train_stop': 'mean'
}).reset_index()

# %%
grouped

# %%
plt.figure(figsize=(10, 6))
plt.bar(grouped['geographic_cluster_name'], grouped['km_to_bus_stop'], label='Average Distance to Bus Stop')
plt.bar(grouped['geographic_cluster_name'], grouped['km_to_train_stop'], label='Average Distance to Train Stop')
plt.xlabel('Neighborhood')
plt.ylabel('Average Distance (km)')
plt.title('Proximity of Neighborhoods to Bus and Train Stops')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.bar(grouped['geographic_cluster_name'], grouped['km_to_train_stop'], label='Average Distance to Train Stop')
plt.xlabel('Neighborhood')
plt.ylabel('Average Distance (km)')
plt.title('Proximity of Neighborhoods to Bus and Train Stops')
plt.xticks(rotation=90)
plt.legend()
plt.show()

# %%
mcmf.program_provides_transportation.value_counts()
# Out:
# NO     72388
# YES       59
# Name: program_provides_transportation, dtype: int64
